# %% [markdown]
# 1. Use ImageDownloader - Imageye to download images in bulk
# 2. Split train-test, and use only train for below
# 2. Use YoloV3_Annotation_Tool to annotate the images - some images had empty .txt files becuase they were too large to annotate
# 3. Get YoloV3 rep cloned and make the changes as noted - use the PR by Akash to fix the errors
# 4. custom.shapes is created during training time
# 5. last check point of model saved in last.pt in weights folder
# 6. empty .txt mentioned above is not a problem as - Caching labels (74 found, 0 missing, 16 empty, 0 duplicate, for 90 images)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/Yolo_stuff/YoloV3/
# Out:
# /content/drive/MyDrive/Yolo_stuff/YoloV3

# %%
ls
# Out:
#  cfg/        __pycache__/   runs/             train_batch0.png    vim.exe.stackdump
#  data/       README.md      test_batch0.png   train.py            weights/
#  detect.py   results.json   test_mojo_jojo/  'ubdivisions=1'
#  models.py   results.png    test.py          'Untitled Folder'/
#  output/     results.txt    ting              utils/

# %%
# !python train.py --data data/smalcoco/smalcoco.data --batch 3 --cache --epochs 3 --nosave
# Out:
# Namespace(epochs=3, batch_size=3, accumulate=4, cfg='cfg/yolov3-spp.cfg', data='data/smalcoco/smalcoco.data', multi_scale=False, img_size=[512], rect=False, resume=False, nosave=True, notest=False, evolve=False, bucket='', cache_images=True, weights='weights/yolov3-spp-ultralytics.pt', name='', device='', adam=False, single_cls=False)
# Using CUDA device0 _CudaDeviceProperties(name='Tesla T4', total_memory=15102MB)
#
# 2024-07-03 18:42:47.676342: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-07-03 18:42:47.676398: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# ...

# %%
# !python train.py --data data/customdata/custom.data --batch 10 --cache --cfg cfg/yolov3-custom.cfg --epochs 300 --nosave
# Out:
# Namespace(epochs=300, batch_size=10, accumulate=4, cfg='cfg/yolov3-custom.cfg', data='data/customdata/custom.data', multi_scale=False, img_size=[512], rect=False, resume=False, nosave=True, notest=False, evolve=False, bucket='', cache_images=True, weights='weights/yolov3-spp-ultralytics.pt', name='', device='', adam=False, single_cls=False)
# Using CUDA device0 _CudaDeviceProperties(name='Tesla T4', total_memory=15102MB)
#
# 2024-07-04 03:35:19.615674: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-07-04 03:35:19.615727: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# ...

# %%
# !python detect.py --source test_mojo_jojo/ --conf-thres 0.1 --output predicted_mojo_jojo
# Out:
# Namespace(cfg='cfg/yolov3-custom.cfg', names='data/customdata/custom.names', weights='weights/last.pt', source='test_mojo_jojo/', output='predicted_mojo_jojo', img_size=512, conf_thres=0.1, iou_thres=0.6, fourcc='mp4v', half=False, device='', view_img=False, save_txt=False, classes=None, agnostic_nms=False, augment=False)
# Using CUDA device0 _CudaDeviceProperties(name='Tesla T4', total_memory=15102MB)
#
# Model Summary: 225 layers, 6.25733e+07 parameters, 6.25733e+07 gradients
# /usr/local/lib/python3.10/dist-packages/torch/functional.py:512: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3587.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# image 1/8 test_mojo_jojo/mojo_jojo_91.jpg: 512x384 1 mojo jojos, Done. (0.044s)
# image 2/8 test_mojo_jojo/mojo_jojo_92.jpg: 448x512 Done. (0.060s)
# ...
